# %%
nums =[2,4,1,2,4,3,2,1]

freq = {}

for n in nums:
    freq[n]= freq.get(n,0)+1

print(freq)
# Out:
# {2: 3, 4: 2, 1: 2, 3: 1}

# %%
from collections import Counter

nums = [2,4,1,2,4,3,2,1]
print(Counter(nums))
# Out:
# Counter({2: 3, 4: 2, 1: 2, 3: 1})
