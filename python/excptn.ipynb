# %%
s = 3,9,7
s

s[0]= 5
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 s = 3,9,7
#       2 s
#       3
# ----> 4 s[0]= 5
#       5 s
#
# TypeError: 'tuple' object does not support item assignment
