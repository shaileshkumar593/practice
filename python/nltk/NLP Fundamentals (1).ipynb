# %%
sms = "Pizza, the delectable and iconic dish that has transcended borders and captivated taste buds 1234 worldwide, is a testament to the extraordinary fusion of flavors, creativity, and cultural significance."

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
import re

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vamsi
# [nltk_data]     Krishna\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
words = sms.lower().split()
words
# Out:
# ['pizza,',
#  'the',
#  'delectable',
#  'and',
#  'iconic',
#  'dish',
#  'that',
#  'has',
#  'transcended',
#  'borders',
#  'and',
#  'captivated',
#  'taste',
#  'buds',
#  '1234',
#  'worldwide,',
#  'is',
#  'a',
#  'testament',
#  'to',
#  'the',
#  'extraordinary',
#  'fusion',
#  'of',
#  'flavors,',
#  'creativity,',
#  'and',
#  'cultural',
#  'significance.']

# %%
words  = word_tokenize(sms.lower())
words
# Out:
# ['pizza',
#  ',',
#  'the',
#  'delectable',
#  'and',
#  'iconic',
#  'dish',
#  'that',
#  'has',
#  'transcended',
#  'borders',
#  'and',
#  'captivated',
#  'taste',
#  'buds',
#  '1234',
#  'worldwide',
#  ',',
#  'is',
#  'a',
#  'testament',
#  'to',
#  'the',
#  'extraordinary',
#  'fusion',
#  'of',
#  'flavors',
#  ',',
#  'creativity',
#  ',',
#  'and',
#  'cultural',
#  'significance',
#  '.']

# %%
words = re.findall(r'\b[a-z]+\b',sms.lower())
words
# Out:
# ['pizza',
#  'the',
#  'delectable',
#  'and',
#  'iconic',
#  'dish',
#  'that',
#  'has',
#  'transcended',
#  'borders',
#  'and',
#  'captivated',
#  'taste',
#  'buds',
#  'worldwide',
#  'is',
#  'a',
#  'testament',
#  'to',
#  'the',
#  'extraordinary',
#  'fusion',
#  'of',
#  'flavors',
#  'creativity',
#  'and',
#  'cultural',
#  'significance']

# %%
text ="Pizza, the delectable and iconic dish that has transcended borders and captivated taste buds worldwide, is a testament to the extraordinary fusion of flavors, creativity, and cultural significance. Originating from the sun-kissed lands of Italy, pizza has evolved into an art form that unites people from diverse backgrounds in a shared love for its mouthwatering combinations. Its history stretches back centuries, with roots tracing back to ancient civilizations like the Greeks, Romans, and Egyptians, who all had their versions of flatbreads adorned with various ingredients. However, it was the vibrant city of Naples, Italy, that birthed the pizza we know and adore today."
text
# Out:
# 'Pizza, the delectable and iconic dish that has transcended borders and captivated taste buds worldwide, is a testament to the extraordinary fusion of flavors, creativity, and cultural significance. Originating from the sun-kissed lands of Italy, pizza has evolved into an art form that unites people from diverse backgrounds in a shared love for its mouthwatering combinations. Its history stretches back centuries, with roots tracing back to ancient civilizations like the Greeks, Romans, and Egyptians, who all had their versions of flatbreads adorned with various ingredients. However, it was the vibrant city of Naples, Italy, that birthed the pizza we know and adore today.'

# %%
sentences = sent_tokenize(text.lower())
sentences
# Out:
# ['pizza, the delectable and iconic dish that has transcended borders and captivated taste buds worldwide, is a testament to the extraordinary fusion of flavors, creativity, and cultural significance.',
#  'originating from the sun-kissed lands of italy, pizza has evolved into an art form that unites people from diverse backgrounds in a shared love for its mouthwatering combinations.',
#  'its history stretches back centuries, with roots tracing back to ancient civilizations like the greeks, romans, and egyptians, who all had their versions of flatbreads adorned with various ingredients.',
#  'however, it was the vibrant city of naples, italy, that birthed the pizza we know and adore today.']

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')
len(stop_words),stop_words
# Out:
# (179,
#  ['i',
#   'me',
#   'my',
#   'myself',
#   'we',
#   'our',
#   'ours',
#   'ourselves',
#   'you',
#   "you're",
#   "you've",
#   "you'll",
#   "you'd",
#   'your',
#   'yours',
#   'yourself',
#   'yourselves',
#   'he',
#   'him',
#   'his',
#   'himself',
#   'she',
#   "she's",
#   'her',
#   'hers',
#   'herself',
#   'it',
#   "it's",
#   'its',
#   'itself',
#   'they',
#   'them',
#   'their',
#   'theirs',
#   'themselves',
#   'what',
#   'which',
#   'who',
#   'whom',
#   'this',
#   'that',
#   "that'll",
#   'these',
#   'those',
#   'am',
#   'is',
#   'are',
#   'was',
#   'were',
#   'be',
#   'been',
#   'being',
#   'have',
#   'has',
#   'had',
#   'having',
#   'do',
#   'does',
#   'did',
#   'doing',
#   'a',
#   'an',
#   'the',
#   'and',
#   'but',
#   'if',
#   'or',
#   'because',
#   'as',
#   'until',
#   'while',
#   'of',
#   'at',
#   'by',
#   'for',
#   'with',
#   'about',
#   'against',
#   'between',
#   'into',
#   'through',
# ...

# %%
text ="originating from the sun-kissed lands of italy, pizza has evolved into an art form that unites people from diverse backgrounds in a shared love for its mouthwatering combinations."
words = re.findall(r'\b[a-z]+\b',text.lower())
print(len(words))
clean_words = [w for w in words if w not in stop_words]
clean_words,len(clean_words)
# Out:
# 29
# (['originating',
#   'sun',
#   'kissed',
#   'lands',
#   'italy',
#   'pizza',
#   'evolved',
#   'art',
#   'form',
#   'unites',
#   'people',
#   'diverse',
#   'backgrounds',
#   'shared',
#   'love',
#   'mouthwatering',
#   'combinations'],
#  17)

# %%
with open('c:/data/pizza.txt',mode='r') as fp:
    text = fp.read()
print(text)
# Out:
# Pizza, the delectable and iconic dish that has transcended borders and captivated taste buds worldwide, is a testament to the extraordinary fusion of flavors, creativity, and cultural significance. Originating from the sun-kissed lands of Italy, pizza has evolved into an art form that unites people from diverse backgrounds in a shared love for its mouthwatering combinations. Its history stretches back centuries, with roots tracing back to ancient civilizations like the Greeks, Romans, and Egyptians, who all had their versions of flatbreads adorned with various ingredients. However, it was the vibrant city of Naples, Italy, that birthed the pizza we know and adore today.
#
# ...

# %%
words = re.findall(r'\b[a-z]+\b',text.lower())
print(len(words))
clean_words = [w for w in words if w not in stop_words]
len(clean_words),len(set(clean_words))
# Out:
# 1711
# (1040, 619)

# %%
set(clean_words)
# Out:
# {'ability',
#  'acceptance',
#  'accessible',
#  'accommodating',
#  'adapt',
#  'adaptability',
#  'addition',
#  'adds',
#  'adore',
#  'adorned',
#  'advancements',
#  'advent',
#  'air',
#  'alike',
#  'allowing',
#  'allure',
#  'alone',
#  'also',
#  'alternative',
#  'alternatives',
#  'american',
#  'ancient',
#  'anticipation',
#  'appeal',
#  'apps',
#  'areas',
#  'arenas',
#  'aroma',
#  'aromatic',
#  'around',
#  'art',
#  'artisanal',
#  'artistry',
#  'artwork',
#  'asian',
#  'aspects',
#  'assimilated',
#  'atmosphere',
#  'augmented',
#  'automation',
#  'availability',
#  'available',
#  'away',
#  'back',
#  'backgrounds',
#  'baked',
#  'bakes',
#  'balance',
#  'based',
#  'basil',
#  'beautiful',
#  'become',
#  'becomes',
#  'becoming',
#  'beginnings',
#  'beloved',
#  'beyond',
#  'billions',
#  'birthed',
#  'birthplace',
#  'blending',
#  'boast',
#  'borders',
#  'boundaries',
#  'boundless',
#  'brazil',
#  'brick',
#  'bright',
#  'bring',
# ...
