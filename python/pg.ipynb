# %%
n = int("Enter number ")

def is_power_of_ten(e, n):
    if n >= 0:
        if pow(10,e) == n:
                print("power of n is ",e)
                return True 
        else:
            return is_power_of_ten(e-1,n)
e = 100

is_power_of_ten(e,n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 n = int("Enter number ")
#       3 def is_power_of_ten(e, n):
#       4     if n >= 0:
#
# ValueError: invalid literal for int() with base 10: 'Enter number '

# %%
import copy

old_list = [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
new_list = copy.copy(old_list)

old_list.append([4, 4, 4])

print("Old list:", old_list)
print("New list:", new_list)

new_list.append([55,99])

print("Old list:", old_list)
print("New list:", new_list)

old_list[2][1]=88
new_list[1][2]=99

print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 1, 1], [2, 2, 2], [3, 3, 3], [4, 4, 4]]
# New list: [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
# Old list: [[1, 1, 1], [2, 2, 2], [3, 3, 3], [4, 4, 4]]
# New list: [[1, 1, 1], [2, 2, 2], [3, 3, 3], [55, 99]]
# Old list: [[1, 1, 1], [2, 2, 99], [3, 88, 3], [4, 4, 4]]
# New list: [[1, 1, 1], [2, 2, 99], [3, 88, 3], [55, 99]]

# %%
import copy

old_list = [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
new_list = copy.deepcopy(old_list)

old_list[1][0] = 'BB'

print("Old list:", old_list)
print("New list:", new_list)

new_list[2][1]=99

print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 1, 1], ['BB', 2, 2], [3, 3, 3]]
# New list: [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
# Old list: [[1, 1, 1], ['BB', 2, 2], [3, 3, 3]]
# New list: [[1, 1, 1], [2, 2, 2], [3, 99, 3]]
